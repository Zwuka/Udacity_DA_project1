# %% [markdown]
# Questions that I want to ask to existing dataset:
# 1. Whata parameters or set of parametres/// so i think i shoud write it in word document/// dsf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hap_score = pd.read_csv('hapiscore_whr.csv')
foreign_depts = pd.read_csv('debt_to_foreigners_by_public_and_private_percent_of_gni.csv')
elect_generated = pd.read_csv('electricity_generation_total.csv')
human_develop = pd.read_csv('hdi_human_development_index.csv')
income_per_capita = pd.read_csv('income_per_person_gdppercapita_ppp_inflation_adjusted.csv')
pop_total = pd.read_csv('population_total.csv')
trade_bal = pd.read_csv('trade_balance_us_not_inflation_adjusted.csv')

# %%
list1 = list(map(list,[hap_score.columns,foreign_depts.columns,elect_generated.columns,human_develop.columns,income_per_capita.columns,pop_total.columns,trade_bal.columns]))
list1
# Out:
# [['country',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013',
#   '2014',
#   '2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019'],
#  ['country',
#   '1970',
#   '1971',
#   '1972',
#   '1973',
#   '1974',
#   '1975',
#   '1976',
#   '1977',
#   '1978',
#   '1979',
#   '1980',
#   '1981',
#   '1982',
#   '1983',
#   '1984',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013',
#   '2014',
#   '2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019'],
#  ['country',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
# ...

# %%
for e,i in enumerate(list1):
    print(e,len(i))
# Out:
# 0 16
# 1 51
# 2 36
# 3 30
# 4 242
# 5 302
# 6 61

# %%
for each in list1:
    print(''.join(list1[0][1:-1]) in ''.join(each))
# Out:
# True
# True
# True
# True
# True
# True
# True

# %%
print(list1[1])
# Out:
# ['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
df_columns = list1[3]
df_list = [hap_score,foreign_depts,elect_generated,human_develop,income_per_capita,pop_total,trade_bal]
df_names = ['happy_score','foreign_depts','electricity_generated','human_develop','income_per_capita','population_total','trade_balance']

# %%
# Out:
# Empty DataFrame
# Columns: [country, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
# Index: []
#
# [0 rows x 30 columns]

# %%
belarus_df = belarus_df.append(foreign_depts.loc[foreign_depts.country == 'Belarus',df_columns])
belarus_df = belarus_df.append(income_per_capita.loc[income_per_capita.country=='Belarus',df_columns])
belarus_df
# Out:
#     country  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...   2009  \
# 12  Belarus   NaN   NaN   NaN  5.95  8.73  12.2  13.3  14.8  15.8  ...   44.1
# 20  Belarus  8370  8260  7450  6870  6070  5460  5630  6300  6860  ...  15.1k
#
#      2010   2011   2012   2013   2014   2015   2016   2017   2018
# 12   50.6   56.2   52.6   54.4   52.4   70.9   82.4   75.2   67.0
# 20  16.3k  17.2k  17.5k  17.6k  17.9k  17.2k  16.8k  17.2k  17.7k
#
# [2 rows x 30 columns]

# %%
belarus_df = pd.DataFrame(columns=df_columns)
belarus_df
# Out:
# Empty DataFrame
# Columns: [country, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
# Index: []
#
# [0 rows x 30 columns]

# %%
x=0
for each in df_list:
    if ''.join(df_columns[1:]) in ''.join(list(each.columns)):
        belarus_df = belarus_df.append(each.loc[each.country == 'Belarus',df_columns])
        belarus_df.iloc[x,0]=df_names[x]
    else:
        belarus_df = belarus_df.append(each.loc[each.country == 'Belarus'])
        belarus_df.iloc[x,0]=df_names[x]       
    x+=1
belarus_df
# Out:
#                   country   1990   1991   1992    1993    1994   1995   1996  \
# 17            happy_score    NaN    NaN    NaN     NaN     NaN    NaN    NaN
# 12          foreign_depts    NaN    NaN    NaN    5.95    8.73   12.2   13.3
# 8   electricity_generated  39.5B  38.7B  37.6B   33.4B   31.4B  24.9B  23.7B
# 20          human_develop    NaN    NaN    NaN     NaN     NaN  0.656  0.661
# 20      income_per_capita   8370   8260   7450    6870    6070   5460   5630
# 20       population_total  10.2M  10.2M  10.2M   10.1M   10.1M  10.1M    10M
# 21          trade_balance   500M      0   370M  −2.56B  −1.92B  −613M  −601M
#
#      1997   1998  ...    2010   2011   2012    2013   2014   2015   2016  \
# 17    NaN    NaN  ...    55.3   52.3   57.5    58.8   58.1   57.2   51.8
# 12   14.8   15.8  ...    50.6   56.2   52.6    54.4   52.4   70.9   82.4
# 8   26.1B  23.5B  ...   34.9B  32.2B  30.8B   31.5B  34.7B  34.2B  33.6B
# ...

# %%
df_pair1 = income_per_capita.loc[:,['country','1990']]
df_pair = income_per_capita.loc[:,['country','1990']]

# %%
clear_pattern = [x for x in set(''.join(df_pair['1990'])) if not x.isdigit()]
clear_pattern
# Out:
# ['k', '.']

# %%
df_pair1 = df_pair[df_pair['1990'].str.contains('k')]
df_pair1
# Out:
#                   country   1990
# 3                 Andorra  28.4k
# 4    United Arab Emirates   112k
# 5               Argentina  11.4k
# 7     Antigua and Barbuda  17.5k
# 8               Australia  28.7k
# ..                    ...    ...
# 177                Turkey  11.4k
# 179                Taiwan  14.7k
# 182               Ukraine  10.5k
# 184         United States  36.8k
# 187             Venezuela  14.6k
#
# [75 rows x 2 columns]

# %%
#Решение по очистке данных
df_pair['1990'] = df_pair['1990'].apply(lambda x: float(x[:-1])*1000 if 'k' in x else float(x))
df_pair
# Out:
#                   country      1990
# 0             Afghanistan    1860.0
# 1                  Angola    4760.0
# 2                 Albania    4460.0
# 3                 Andorra   28400.0
# 4    United Arab Emirates  112000.0
# ..                    ...       ...
# 190                 Samoa    3650.0
# 191                 Yemen    3430.0
# 192          South Africa    9900.0
# 193                Zambia    2340.0
# 194              Zimbabwe    2820.0
#
# [195 rows x 2 columns]

# %%
df1= corrupt_index[corrupt_index.country=='Belarus']
df1
# Out:
#     country  2012  2013  2014  2015  2016  2017
# 18  Belarus  31.0  29.0  31.0  32.0  40.0  44.0
